# %% [markdown]
# # DESC:     Remove duplicate records from a CSV file
# ## CAUTION:  Script is work in progess. No warranties of any
# ##           kind are provided
# ### AUTHOR:   Patty Jula
# ### DATE:     2019

# %% [markdown]
# ## Run this script second, after checking for existence of duplicates

# %%
from __future__ import print_function
from datetime import datetime
import time
import pandas as pd
import csv
from pathlib import Path

# %%
print("Start time: " + str(datetime.now()))
# Out:
# Start time: 2019-03-03 18:20:28.904587

# %%
# Define files
file_in = "Resources/Police_Department_Incident_Reports__2018_to_Present.csv"
file_out ='Resources/SFPD_clean.csv'

df= pd.read_csv(file_in)
df.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2018/10/22 10:50:00 AM    2018/10/22         10:50           2018
# 1  2018/08/24 02:50:00 PM    2018/08/24         14:50           2018
# 2  2018/10/14 02:54:00 PM    2018/10/14         14:54           2018
# 3  2018/10/14 02:54:00 PM    2018/10/14         14:54           2018
# 4  2018/10/18 04:40:00 PM    2018/10/18         16:40           2018
#
#   Incident Day of Week         Report Datetime       Row ID  Incident ID  \
# 0               Monday  2018/10/22 11:24:00 AM  72897505073       728975
# 1               Friday  2018/08/24 02:52:00 PM  72925174010       729251
# 2               Sunday  2018/10/24 01:10:00 PM  72980906303       729809
# 3               Sunday  2018/10/24 01:10:00 PM  72980964070       729809
# 4             Thursday  2018/10/26 07:42:00 AM  73011316650       730113
#
#    Incident Number   CAD Number  ...                   Incident Description  \
# ...

# %%
# Check if duplicate file is found before running to make clean file
file_out_dupes = Path('Resources/SFPD_duplicates.csv')
if file_out_dupes.is_file():
    print("Duplicates found")
    # CSV module to specify input and out files
    df.drop_duplicates(subset='Incident Number', keep='last', inplace=True)
else:
    pass
# Out:
# Duplicates found

# %%
df.head()
# Out:
#          Incident Datetime Incident Date Incident Time  Incident Year  \
# 1   2018/08/24 02:50:00 PM    2018/08/24         14:50           2018
# 3   2018/10/14 02:54:00 PM    2018/10/14         14:54           2018
# 7   2018/10/25 07:45:00 AM    2018/10/25         07:45           2018
# 9   2018/10/25 03:00:00 AM    2018/10/25         03:00           2018
# 11  2018/10/20 11:15:00 PM    2018/10/20         23:15           2018
#
#    Incident Day of Week         Report Datetime       Row ID  Incident ID  \
# 1                Friday  2018/08/24 02:52:00 PM  72925174010       729251
# 3                Sunday  2018/10/24 01:10:00 PM  72980964070       729809
# 7              Thursday  2018/10/25 07:51:00 AM  73012764020       730127
# 9              Thursday  2018/10/25 07:39:00 AM  73016503074       730165
# 11             Saturday  2018/10/25 01:20:00 PM  73019004013       730190
#
#     Incident Number   CAD Number  ...                  Incident Description  \
# ...

# %% [markdown]
# ### Check given Incident ID

# %%
# Create query
df.loc[df['Incident ID'] == 618910]
# Out:
#             Incident Datetime Incident Date Incident Time  Incident Year  \
# 58544  2018/01/01 05:20:00 AM    2018/01/01         05:20           2018
#
#       Incident Day of Week         Report Datetime       Row ID  Incident ID  \
# 58544               Monday  2018/01/01 05:28:00 AM  61891012168       618910
#
#        Incident Number   CAD Number  ...  \
# 58544        180000570  180011009.0  ...
#
#                                  Incident Description            Resolution  \
# 58544  Firearm, Loaded, in Vehicle, Possession or Use  Cite or Arrest Adult
#
#               Intersection         CNN Police District  \
# 58544  02ND ST \ FOLSOM ST  24519000.0        Southern
#
#                 Analysis Neighborhood Supervisor District   Latitude  \
# 58544  Financial District/South Beach                 6.0  37.785542
#
#         Longitude                                     point
# 58544 -122.396705  (37.78554213006711, -122.39670517825668)
#
# [1 rows x 26 columns]
